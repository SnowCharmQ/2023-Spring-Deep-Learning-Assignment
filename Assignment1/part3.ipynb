# %% [markdown]
# # Part 3

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from optimizer import *
from mlp_numpy import *
from sklearn import datasets

# %%
# Default constants
DNN_HIDDEN_UNITS_DEFAULT = '20'
LEARNING_RATE_DEFAULT = 1e-2
MAX_EPOCHS_DEFAULT = 1500
EVAL_FREQ_DEFAULT = 300

# %%
dnn_hidden_units = DNN_HIDDEN_UNITS_DEFAULT
n_hidden = dnn_hidden_units.split(",")
n_hidden = [int(x) for x in n_hidden]
learning_rate = LEARNING_RATE_DEFAULT
max_steps = MAX_EPOCHS_DEFAULT
eval_freq = EVAL_FREQ_DEFAULT

# %%
inputs, labels = datasets.make_moons(n_samples=1000, shuffle=True)

# %%
mlp = MLP(2, n_hidden, 2)
optimizer = SGD(mlp)
optimizer.optimize(inputs, labels, learning_rate, max_steps, eval_freq)
# Out:
# SGD Epoch 0:
# Average Train Loss: 0.6948845569571596 | Average Train Accuracy: 0.49875
# Average Test Loss: 0.6945542018725809 | Average Test Accuracy: 0.5
#
# SGD Epoch 300:
# Average Train Loss: 0.2405422516645388 | Average Train Accuracy: 0.89
# Average Test Loss: 0.2541458925254436 | Average Test Accuracy: 0.87
#
# SGD Epoch 600:
# Average Train Loss: 0.24023721476574766 | Average Train Accuracy: 0.89
# Average Test Loss: 0.26239573882676237 | Average Test Accuracy: 0.86
#
# SGD Epoch 900:
# Average Train Loss: 0.24106442069051506 | Average Train Accuracy: 0.88875
# Average Test Loss: 0.2579938520389362 | Average Test Accuracy: 0.865
#
# SGD Epoch 1200:
# Average Train Loss: 0.2347340023779587 | Average Train Accuracy: 0.8875
# Average Test Loss: 0.2504153353009872 | Average Test Accuracy: 0.885
#
# SGD Epoch 1499:
# Average Train Loss: 0.24075273252215934 | Average Train Accuracy: 0.8875
# Average Test Loss: 0.2522253539760718 | Average Test Accuracy: 0.875
# Best Train Loss: 0.23111611122066922 | Best Train Accuracy: 0.9
# Best Test Loss: 0.24711865700738023 | Best Test Accuracy: 0.905
