# %% [markdown]
# # Part 2

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from optimizer import *
from mlp_numpy import *
from sklearn import datasets

# %%
# Default constants
DNN_HIDDEN_UNITS_DEFAULT = '20'
LEARNING_RATE_DEFAULT = 1e-2
MAX_EPOCHS_DEFAULT = 1500
EVAL_FREQ_DEFAULT = 300

# %%
dnn_hidden_units = DNN_HIDDEN_UNITS_DEFAULT
n_hidden = dnn_hidden_units.split(",")
n_hidden = [int(x) for x in n_hidden]
learning_rate = LEARNING_RATE_DEFAULT
max_steps = MAX_EPOCHS_DEFAULT
eval_freq = EVAL_FREQ_DEFAULT

# %%
inputs, labels = datasets.make_moons(n_samples=1000, shuffle=True)

# %%
mlp = MLP(2, n_hidden, 2)
optimizer = BGD(mlp)
optimizer.optimize(inputs, labels, learning_rate, max_steps, eval_freq)
# Out:
# BGD Epoch 0:
# Average Train Loss: 0.6931471794083924 | Average Train Accuracy: 0.52
# Average Test Loss: 0.6931503056044872 | Average Test Accuracy: 0.475
#
# BGD Epoch 300:
# Average Train Loss: 0.693072761962734 | Average Train Accuracy: 0.50625
# Average Test Loss: 0.6936811805664785 | Average Test Accuracy: 0.475
#
# BGD Epoch 600:
# Average Train Loss: 0.6930681355595038 | Average Train Accuracy: 0.50625
# Average Test Loss: 0.6938109894873705 | Average Test Accuracy: 0.475
#
# BGD Epoch 900:
# Average Train Loss: 0.6930610366524707 | Average Train Accuracy: 0.50625
# Average Test Loss: 0.6938337697950655 | Average Test Accuracy: 0.475
#
# BGD Epoch 1200:
# Average Train Loss: 0.6930106688219392 | Average Train Accuracy: 0.50625
# Average Test Loss: 0.6937901448019468 | Average Test Accuracy: 0.475
#
# BGD Epoch 1499:
# Average Train Loss: 0.6926459164389381 | Average Train Accuracy: 0.50625
# Average Test Loss: 0.6934281640147464 | Average Test Accuracy: 0.475
# Best Train Loss: 0.6926459164389381 | Best Train Accuracy: 0.52
# Best Test Loss: 0.6931503056044872 | Best Test Accuracy: 0.475
